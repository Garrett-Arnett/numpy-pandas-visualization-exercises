# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pydataset import data

# %%
'''Use the iris database to answer the following quesitons:'''

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 7             5.0          3.4           1.5          0.2      setosa
# 8             4.4          2.9           1.4          0.2      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 10            5.4          3.7           1.5          0.2      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# ...

# %%
# 1. What does the distribution of petal lengths look like?

sns.displot(iris.petal_length, kde = True)

# %%
# 2. Is there a correlation between petal length and petal width? Use 
# http://guessthecorrelation.com/ as a hint to how we could visually determine 
# if a correlation exists between two numeric columns.
sns.relplot(x = 'petal_length', y = "petal_width", data = iris, hue = 'species')
plt.show()

# there is a correlation between the two for the species

# %%
# 3. Would it be reasonable to predict species based on sepal width and sepal length? 
# For this, you'll visualize two numeric columns through the lense of a 
# categorical column.
sns.relplot(x = 'sepal_length', y = "sepal_width", data = iris, hue = 'species')
plt.show()

# it would be only possible to tell if the species will be a setosa or not. 
# the versicolor and virginica are to closely related.

# %%
# 4. Which features would be best used to predict species?

sns.relplot(x = 'petal_length', y = "petal_width", data = iris, hue = 'species')
plt.show()


# one can determin the species using this graph.

# %%
sns.pairplot(data = iris, hue = 'species')
plt.show()

# %%
'''Using the lesson as an example, use seaborn's load_dataset function to
load the anscombe data set. Use pandas to group the data by the dataset column,
and calculate summary statistics for each dataset.'''

# %%
anscombe = sns.load_dataset('anscombe')
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
# 1. What do you notice? Plot the x and y values from the anscombe data. 
# Each dataset should be in a separate column.

sns.relplot(data = anscombe, x = 'x', y = 'y', hue = 'dataset')
plt.show()

# %%
sns.relplot(data = anscombe, x = 'x', y = 'y', col = 'dataset')
plt.show()

# %%
sns.lmplot(data = anscombe, x = 'x', y = 'y', col = 'dataset')
plt.show()

# %%
# 2. Load the InsectSprays dataset and read it's documentation. Create a boxplot that 
# shows the effectiveness of the different insect sprays.
InsectSprays = data("InsectSprays") 
InsectSprays
# Out:
#     count spray
# 1      10     A
# 2       7     A
# 3      20     A
# 4      14     A
# 5      14     A
# 6      12     A
# 7      10     A
# 8      23     A
# 9      17     A
# 10     20     A
# 11     14     A
# 12     13     A
# 13     11     B
# 14     17     B
# 15     21     B
# 16     11     B
# 17     16     B
# 18     14     B
# 19     17     B
# 20     17     B
# 21     19     B
# 22     21     B
# 23      7     B
# 24     13     B
# 25      0     C
# 26      1     C
# 27      7     C
# 28      2     C
# 29      3     C
# 30      1     C
# 31      2     C
# 32      1     C
# 33      3     C
# 34      0     C
# 35      1     C
# 36      4     C
# 37      3     D
# 38      5     D
# 39     12     D
# 40      6     D
# 41      4     D
# 42      3     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      5     D
# 47      2     D
# 48      4     D
# 49      3     E
# 50      5     E
# 51      3     E
# 52      5     E
# 53      3     E
# 54      6     E
# ...

# %%
sns.boxplot(data = InsectSprays, x = 'spray', y = 'count') 
plt.show()

# %%
# 3. Load the swiss dataset and read it's documentation. The swiss dataset is available 
# from pydatset rather than seaborn. Create visualizations to answer the following 
# questions:

#Create an attribute named is_catholic that holds a boolean value of whether or
#      not the province is Catholic. (Choose a cutoff point for what constitutes catholic)
#Does whether or not a province is Catholic influence fertility?
#What measure correlates most strongly with fertility?

swiss = data("swiss") 
swiss
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
is_cath = swiss.Catholic
is_catholic = swiss.assign(is_cath = swiss.Catholic >= 60)
is_catholic
# Out:
#               Fertility  Agriculture  Examination  Education  Catholic  \
# Courtelary         80.2         17.0           15         12      9.96
# Delemont           83.1         45.1            6          9     84.84
# Franches-Mnt       92.5         39.7            5          5     93.40
# Moutier            85.8         36.5           12          7     33.77
# Neuveville         76.9         43.5           17         15      5.16
# Porrentruy         76.1         35.3            9          7     90.57
# Broye              83.8         70.2           16          7     92.85
# Glane              92.4         67.8           14          8     97.16
# Gruyere            82.4         53.3           12          7     97.67
# Sarine             82.9         45.2           16         13     91.38
# Veveyse            87.1         64.5           14          6     98.61
# Aigle              64.1         62.0           21         12      8.52
# ...

# %%
sns.relplot(data = is_catholic, x = 'Catholic', y = 'Fertility', hue = is_catholic.is_cath)
plt.show()

# %%
sns.pairplot(swiss) 
plt.show()

# %%
swiss.corr().Fertility
# Out:
# Fertility           1.000000
# Agriculture         0.353079
# Examination        -0.645883
# Education          -0.663789
# Catholic            0.463685
# Infant.Mortality    0.416556
# Name: Fertility, dtype: float64

# %%
# 4. Using the chipotle dataset from the previous exercise, create a bar chart that
# shows the 4 most popular items and the revenue produced by each.
from env import host, user, password
url = f'mysql+pymysql://{user}:{password}@{host}/chipotle'
query = """
    SELECT * FROM orders
"""
orders = pd.read_sql(query, url)
orders
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
df = pd.Series(orders.item_price)
df = df.str.replace('$', '',regex=False)
df = df.str.replace(',','')
df = df.astype(float)

sum_of_food = (orders.assign(price2 = df))

pd.DataFrame(sum_of_food.groupby(["order_id"]).price2.sum())

most_mula = pd.DataFrame(sum_of_food.groupby(["item_name"]).price2.sum())

most_mula.nlargest(3, 'price2', keep='all')
price2 = sum_of_food.price2
price2
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#         ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: price2, Length: 4622, dtype: float64

# %%
pop_orders = pd.DataFrame(orders.groupby(["item_name"]).quantity.sum())
pop_orders.nlargest(4, 'quantity', keep='all')

pop_orders = (pop_orders.assign(price2 = most_mula.price2).sort_values(by = 'quantity', ascending = False))
pop_orders = pop_orders.head(4)

pop_orders = sns.barplot(x = 'quantity', y = 'price2', data = pop_orders, hue = pop_orders.index)
plt.show()

# %%
# 5. Load the sleepstudy data and read it's documentation. Use seaborn to create a line
# chart of all the individual subject's reaction times and a more prominant line 
# showing the average change in reaction time.

sleepstudy = data("sleepstudy") 
sleepstudy
# Out:
#      Reaction  Days  Subject
# 1    249.5600     0      308
# 2    258.7047     1      308
# 3    250.8006     2      308
# 4    321.4398     3      308
# 5    356.8519     4      308
# ..        ...   ...      ...
# 176  329.6076     5      372
# 177  334.4818     6      372
# 178  343.2199     7      372
# 179  369.1417     8      372
# 180  364.1236     9      372
#
# [180 rows x 3 columns]

# %%
plt.figure(figsize=(20,10))
sns.pointplot(data = sleepstudy, x = "Days", y = "Reaction", hue = 'Subject')
plt.show()

# %%
avg = pd.DataFrame(sleepstudy.groupby(["Days"]).Reaction.mean())
avg.plot.line()
plt.show()
